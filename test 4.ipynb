# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study
adata = sc.read_h5ad("all_cells.h5ad")

# Subset to CD8+ lymphocytes if they are labeled
adata_cd8 = adata[adata.obs['cell_type'] == 'CD8+ lymphocyte']

# Extract relevant data
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[1], line 15
#      12     os.makedirs(output_dir)
#      14 # Load the .h5ad file from the study
# ---> 15 adata = sc.read_h5ad("all_cells.h5ad")
#      17 # Subset to CD8+ lymphocytes if they are labeled
#      18 adata_cd8 = adata[adata.obs['cell_type'] == 'CD8+ lymphocyte']
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\h5ad.py:258, in read_h5ad(filename, backed, as_sparse, as_sparse_fmt, chunk_size)
#     255         return read_dataframe(elem)
#     256     return func(elem)
# --> 258 adata = read_dispatched(f, callback=callback)
#     260 # Backwards compat (should figure out which version)
#     261 if "raw.X" in f:
#
# File ~\anaconda3\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\utils.py:211, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     209     raise ValueError("No element found in args.")
#     210 try:
# --> 211     return func(*args, **kwargs)
#     212 except Exception as e:
#     213     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\specs\registry.py:275, in Reader.read_elem(self, elem, modifiers)
#     273 if self.callback is None:
#     274     return read_func(elem)
# --> 275 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\h5ad.py:242, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     236 def callback(func, elem_name: str, elem, iospec):
#     237     if iospec.encoding_type == "anndata" or elem_name.endswith("/"):
#     238         return AnnData(
#     239             **{
#     240                 # This is covering up backwards compat in the anndata initializer
#     241                 # In most cases we should be able to call `func(elen[k])` instead
# --> 242                 k: read_dispatched(elem[k], callback)
#     243                 for k in elem.keys()
#     244                 if not k.startswith("raw.")
#     245             }
#     246         )
#     247     elif elem_name.startswith("/raw."):
#     248         return None
#
# File ~\anaconda3\Lib\site-packages\anndata\experimental\_dispatch_io.py:42, in read_dispatched(elem, callback)
#      38 from anndata._io.specs import _REGISTRY, Reader
#      40 reader = Reader(_REGISTRY, callback=callback)
# ---> 42 return reader.read_elem(elem)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\utils.py:211, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     209     raise ValueError("No element found in args.")
#     210 try:
# --> 211     return func(*args, **kwargs)
#     212 except Exception as e:
#     213     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\specs\registry.py:275, in Reader.read_elem(self, elem, modifiers)
#     273 if self.callback is None:
#     274     return read_func(elem)
# --> 275 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\h5ad.py:252, in read_h5ad.<locals>.callback(func, elem_name, elem, iospec)
#     250     return rdasp(elem)
#     251 elif elem_name == "/raw":
# --> 252     return _read_raw(f, as_sparse, rdasp)
#     253 elif elem_name in {"/obs", "/var"}:
#     254     # Backwards compat
#     255     return read_dataframe(elem)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\h5ad.py:285, in _read_raw(f, as_sparse, rdasp, attrs)
#     283 if "X" in attrs and "raw/X" in f:
#     284     read_x = rdasp if "raw/X" in as_sparse else read_elem
# --> 285     raw["X"] = read_x(f["raw/X"])
#     286 for v in ("var", "varm"):
#     287     if v in attrs and f"raw/{v}" in f:
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\specs\registry.py:351, in read_elem(elem)
#     339 def read_elem(elem: StorageType) -> InMemoryElem:
#     340     """
#     341     Read an element from a store.
#     342
#    (...)
#     349         The stored element.
#     350     """
# --> 351     return Reader(_REGISTRY).read_elem(elem)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\utils.py:211, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     209     raise ValueError("No element found in args.")
#     210 try:
# --> 211     return func(*args, **kwargs)
#     212 except Exception as e:
#     213     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\specs\registry.py:274, in Reader.read_elem(self, elem, modifiers)
#     272 read_func = self.registry.get_read(type(elem), iospec, modifiers, reader=self)
#     273 if self.callback is None:
# --> 274     return read_func(elem)
#     275 return self.callback(read_func, elem.name, elem, iospec=iospec)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\specs\methods.py:142, in read_basic(elem, _reader)
#     140     return {k: _reader.read_elem(v) for k, v in elem.items()}
#     141 elif isinstance(elem, h5py.Dataset):
# --> 142     return h5ad.read_dataset(elem)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\utils.py:211, in report_read_key_on_error.<locals>.func_wrapper(*args, **kwargs)
#     209     raise ValueError("No element found in args.")
#     210 try:
# --> 211     return func(*args, **kwargs)
#     212 except Exception as e:
#     213     path, key = _get_display_path(store).rsplit("/", 1)
#
# File ~\anaconda3\Lib\site-packages\anndata\_io\h5ad.py:326, in read_dataset(dataset)
#     324     if (string_dtype is not None) and (string_dtype.encoding == "utf-8"):
#     325         dataset = dataset.asstr()
# --> 326 value = dataset[()]
#     327 if not hasattr(value, "dtype"):
#     328     return value
#
# File h5py\\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File ~\anaconda3\Lib\site-packages\h5py\_hl\dataset.py:758, in Dataset.__getitem__(self, args, new_dtype)
#     756 if self._fast_read_ok and (new_dtype is None):
#     757     try:
# --> 758         return self._fast_reader.read(args)
#     759     except TypeError:
#     760         pass  # Fall back to Python read pathway below
#
# File h5py\\_selector.pyx:368, in h5py._selector.Reader.read()
#
# File h5py\\_selector.pyx:342, in h5py._selector.Reader.make_array()
#
# MemoryError: Unable to allocate 4.65 GiB for an array with shape (41976, 29766) and data type float32
# Error raised while reading key 'X' of <class 'h5py._hl.dataset.Dataset'> from /raw

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Subset to CD8+ lymphocytes if they are labeled
adata_cd8 = adata[adata.obs['cell_type'] == 'CD8+ lymphocyte']

# Extract relevant data in backed mode
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.toarray().flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.toarray().flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cell_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 18
#      15 adata = sc.read_h5ad("all_cells.h5ad", backed='r')
#      17 # Subset to CD8+ lymphocytes if they are labeled
# ---> 18 adata_cd8 = adata[adata.obs['cell_type'] == 'CD8+ lymphocyte']
#      20 # Extract relevant data in backed mode
#      21 data_clustering = pd.DataFrame({
#      22     'GZMB': adata_cd8[:, 'GZMB'].X.toarray().flatten(),
#      23     'GNLY': adata_cd8[:, 'GNLY'].X.toarray().flatten()
#      24 })
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'cell_type'

# %%
import scanpy as sc

# Load the .h5ad file in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Print the available observation columns
print("Obs columns:", adata.obs.columns)
# Out:
# Obs columns: Index(['sample', 'batch', 'doublet_scores', 'predicted_doublet',
#        'n_genes_by_counts', 'log1p_n_genes_by_counts', 'total_counts',
#        'log1p_total_counts', 'percent_mito', 'M.Number', 'treatment',
#        'infection dose', 'Tissue name', 'CFU/granuloma', 'total thoracic CFU',
#        'lung region', 'Gran State', 'n_counts', 'n_genes',
#        'General Celltypes'],
#       dtype='object')

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Subset to CD8+ lymphocytes if they are labeled
adata_cd8 = adata[adata.obs['General Celltypes'] == 'CD8+ lymphocyte']

# Extract relevant data in backed mode
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 22
#      18 adata_cd8 = adata[adata.obs['General Celltypes'] == 'CD8+ lymphocyte']
#      20 # Extract relevant data in backed mode
#      21 data_clustering = pd.DataFrame({
# ---> 22     'GZMB': adata_cd8[:, 'GZMB'].X.flatten(),
#      23     'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
#      24 })
#      25 data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values
#      27 # Apply KMeans clustering
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1022, in AnnData.__getitem__(self, index)
#    1020 """Returns a sliced view of the object."""
#    1021 oidx, vidx = self._normalize_indices(index)
# -> 1022 return AnnData(self, oidx=oidx, vidx=vidx, asview=True)
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:252, in AnnData.__init__(self, X, obs, var, uns, obsm, varm, layers, raw, dtype, shape, filename, filemode, asview, obsp, varp, oidx, vidx)
#     250     if not isinstance(X, AnnData):
#     251         raise ValueError("`X` has to be an AnnData object.")
# --> 252     self._init_as_view(X, oidx, vidx)
#     253 else:
#     254     self._init_as_actual(
#     255         X=X,
#     256         obs=obs,
#    (...)
#     268         filemode=filemode,
#     269     )
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:273, in AnnData._init_as_view(self, adata_ref, oidx, vidx)
#     271 def _init_as_view(self, adata_ref: AnnData, oidx: Index, vidx: Index):
#     272     if adata_ref.isbacked and adata_ref.is_view:
# --> 273         raise ValueError(
#     274             "Currently, you cannot index repeatedly into a backed AnnData, "
#     275             "that is, you cannot make a view of a view."
#     276         )
#     277     self._is_view = True
#     278     if isinstance(oidx, (int, np.integer)):
#
# ValueError: Currently, you cannot index repeatedly into a backed AnnData, that is, you cannot make a view of a view.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Extract relevant observation indices
cd8_indices = adata.obs.index[adata.obs['General Celltypes'] == 'CD8+ lymphocyte']
adata_cd8 = adata[cd8_indices, :].to_memory()

# Extract relevant data in backed mode
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 30
#      28 # Apply KMeans clustering
#      29 kmeans = KMeans(n_clusters=3, random_state=42)
# ---> 30 data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])
#      32 # Visualize GZMB and GNLY expression within clusters
#      33 gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1071, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1048 def fit_predict(self, X, y=None, sample_weight=None):
#    1049     """Compute cluster centers and predict cluster index for each sample.
#    1050
#    1051     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1069         Index of the cluster each sample belongs to.
#    1070     """
# -> 1071     return self.fit(X, sample_weight=sample_weight).labels_
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1481, in KMeans.fit(self, X, y, sample_weight)
#    1453 @_fit_context(prefer_skip_nested_validation=True)
#    1454 def fit(self, X, y=None, sample_weight=None):
#    1455     """Compute k-means clustering.
#    1456
#    1457     Parameters
#    (...)
#    1479         Fitted estimator.
#    1480     """
# -> 1481     X = self._validate_data(
#    1482         X,
#    1483         accept_sparse="csr",
#    1484         dtype=[np.float64, np.float32],
#    1485         order="C",
#    1486         copy=self.copy_x,
#    1487         accept_large_sparse=False,
#    1488     )
#    1490     self._check_params_vs_input(X)
#    1492     random_state = check_random_state(self.random_state)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by KMeans.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Subset to CD8 expressing cells
adata_cd8 = adata[adata.obs['General Celltypes'] == 'CD8']

# Extract relevant data in backed mode
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 22
#      18 adata_cd8 = adata[adata.obs['General Celltypes'] == 'CD8']
#      20 # Extract relevant data in backed mode
#      21 data_clustering = pd.DataFrame({
# ---> 22     'GZMB': adata_cd8[:, 'GZMB'].X.flatten(),
#      23     'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
#      24 })
#      25 data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values
#      27 # Apply KMeans clustering
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1022, in AnnData.__getitem__(self, index)
#    1020 """Returns a sliced view of the object."""
#    1021 oidx, vidx = self._normalize_indices(index)
# -> 1022 return AnnData(self, oidx=oidx, vidx=vidx, asview=True)
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:252, in AnnData.__init__(self, X, obs, var, uns, obsm, varm, layers, raw, dtype, shape, filename, filemode, asview, obsp, varp, oidx, vidx)
#     250     if not isinstance(X, AnnData):
#     251         raise ValueError("`X` has to be an AnnData object.")
# --> 252     self._init_as_view(X, oidx, vidx)
#     253 else:
#     254     self._init_as_actual(
#     255         X=X,
#     256         obs=obs,
#    (...)
#     268         filemode=filemode,
#     269     )
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:273, in AnnData._init_as_view(self, adata_ref, oidx, vidx)
#     271 def _init_as_view(self, adata_ref: AnnData, oidx: Index, vidx: Index):
#     272     if adata_ref.isbacked and adata_ref.is_view:
# --> 273         raise ValueError(
#     274             "Currently, you cannot index repeatedly into a backed AnnData, "
#     275             "that is, you cannot make a view of a view."
#     276         )
#     277     self._is_view = True
#     278     if isinstance(oidx, (int, np.integer)):
#
# ValueError: Currently, you cannot index repeatedly into a backed AnnData, that is, you cannot make a view of a view.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Subset to CD8 expressing cells
cd8_indices = adata.obs.index[adata.obs['General Celltypes'] == 'CD8+ T cells']

# Bring the subset to memory
adata_cd8 = adata[cd8_indices, :].copy()

# Extract relevant data
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.toarray().flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.toarray().flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 21
#      18 cd8_indices = adata.obs.index[adata.obs['General Celltypes'] == 'CD8+ T cells']
#      20 # Bring the subset to memory
# ---> 21 adata_cd8 = adata[cd8_indices, :].copy()
#      23 # Extract relevant data
#      24 data_clustering = pd.DataFrame({
#      25     'GZMB': adata_cd8[:, 'GZMB'].X.toarray().flatten(),
#      26     'GNLY': adata_cd8[:, 'GNLY'].X.toarray().flatten()
#      27 })
#
# File ~\anaconda3\Lib\site-packages\anndata\_core\anndata.py:1448, in AnnData.copy(self, filename)
#    1445 from .._io import read_h5ad, write_h5ad
#    1447 if filename is None:
# -> 1448     raise ValueError(
#    1449         "To copy an AnnData object in backed mode, "
#    1450         "pass a filename: `.copy(filename='myfilename.h5ad')`. "
#    1451         "To load the object into memory, use `.to_memory()`."
#    1452     )
#    1453 mode = self.file._filemode
#    1454 write_h5ad(filename, self)
#
# ValueError: To copy an AnnData object in backed mode, pass a filename: `.copy(filename='myfilename.h5ad')`. To load the object into memory, use `.to_memory()`.

# %%
import scanpy as sc
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from scipy.stats import spearmanr
import os

# Create output directory if it doesn't exist
output_dir = "output"
if not os.path.exists(output_dir):
    os.makedirs(output_dir)

# Load the .h5ad file from the study in backed mode
adata = sc.read_h5ad("all_cells.h5ad", backed='r')

# Subset to CD8 expressing cells
cd8_indices = adata.obs.index[adata.obs['General Celltypes'] == 'CD8']

# Bring the subset to memory
adata_cd8 = adata[cd8_indices, :].to_memory()

# Extract relevant data
data_clustering = pd.DataFrame({
    'GZMB': adata_cd8[:, 'GZMB'].X.flatten(), 
    'GNLY': adata_cd8[:, 'GNLY'].X.flatten()
})
data_clustering['CFU/granuloma'] = adata_cd8.obs['CFU/granuloma'].values

# Apply KMeans clustering
kmeans = KMeans(n_clusters=3, random_state=42)
data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])

# Visualize GZMB and GNLY expression within clusters
gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
plt.title('GZMB vs GNLY within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('GNLY Expression')
plt.savefig(os.path.join(output_dir, 'GZMB_vs_GNLY_Clusters.png'))
plt.show()

# Visualize GZMB expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GZMB'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GZMB Expression vs CFU/granuloma within Clusters')
plt.xlabel('GZMB Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GZMB_vs_CFU_Clusters.png'))
plt.show()

# Visualize GNLY expression and CFU/granuloma within clusters
plt.figure(figsize=(10, 6))
sns.scatterplot(x=data_clustering['GNLY'], y=data_clustering['CFU/granuloma'], hue=data_clustering['Cluster'], palette='coolwarm', alpha=0.6)
plt.title('GNLY Expression vs CFU/granuloma within Clusters')
plt.xlabel('GNLY Expression')
plt.ylabel('CFU/granuloma')
plt.legend(title='Cluster')
plt.grid(True)
plt.savefig(os.path.join(output_dir, 'GNLY_vs_CFU_Clusters.png'))
plt.show()

# Compare GZMB and GNLY Expression within Clusters
for cluster in data_clustering['Cluster'].unique():
    cluster_data = data_clustering[data_clustering['Cluster'] == cluster]
    for gene in ['GZMB', 'GNLY']:
        correlation, p_value = spearmanr(cluster_data[gene], cluster_data['CFU/granuloma'])
        print(f"Cluster {cluster}:")
        print(f"  Correlation between {gene} and CFU/granuloma: {correlation:.2f} (p-value: {p_value:.2e})")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 32
#      30 # Apply KMeans clustering
#      31 kmeans = KMeans(n_clusters=3, random_state=42)
# ---> 32 data_clustering['Cluster'] = kmeans.fit_predict(data_clustering[['GZMB', 'GNLY']])
#      34 # Visualize GZMB and GNLY expression within clusters
#      35 gzm_gnly_scatter = sns.lmplot(x='GZMB', y='GNLY', data=data_clustering, hue='Cluster', palette='coolwarm', fit_reg=False, height=6, aspect=1.5)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1071, in _BaseKMeans.fit_predict(self, X, y, sample_weight)
#    1048 def fit_predict(self, X, y=None, sample_weight=None):
#    1049     """Compute cluster centers and predict cluster index for each sample.
#    1050
#    1051     Convenience method; equivalent to calling fit(X) followed by
#    (...)
#    1069         Index of the cluster each sample belongs to.
#    1070     """
# -> 1071     return self.fit(X, sample_weight=sample_weight).labels_
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1481, in KMeans.fit(self, X, y, sample_weight)
#    1453 @_fit_context(prefer_skip_nested_validation=True)
#    1454 def fit(self, X, y=None, sample_weight=None):
#    1455     """Compute k-means clustering.
#    1456
#    1457     Parameters
#    (...)
#    1479         Fitted estimator.
#    1480     """
# -> 1481     X = self._validate_data(
#    1482         X,
#    1483         accept_sparse="csr",
#    1484         dtype=[np.float64, np.float32],
#    1485         order="C",
#    1486         copy=self.copy_x,
#    1487         accept_large_sparse=False,
#    1488     )
#    1490     self._check_params_vs_input(X)
#    1492     random_state = check_random_state(self.random_state)
#
# File ~\anaconda3\Lib\site-packages\sklearn\base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File ~\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1072, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1070     n_samples = _num_samples(array)
#    1071     if n_samples < ensure_min_samples:
# -> 1072         raise ValueError(
#    1073             "Found array with %d sample(s) (shape=%s) while a"
#    1074             " minimum of %d is required%s."
#    1075             % (n_samples, array.shape, ensure_min_samples, context)
#    1076         )
#    1078 if ensure_min_features > 0 and array.ndim == 2:
#    1079     n_features = array.shape[1]
#
# ValueError: Found array with 0 sample(s) (shape=(0, 2)) while a minimum of 1 is required by KMeans.
