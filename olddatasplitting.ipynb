# %%
# code written by Abhishek Sule @ Chatham University, M.S. Biology for use with Single Cell Portal by Broad Institute

import pandas as pd
import anndata
import os
from watchdog.observers import Observer
from watchdog.events import FileSystemEventHandler

# Load the data
print("Loading data...")
adata = anndata.read_h5ad("all_cells.h5ad")
arrays = list(adata.obs.index)  # the names of the arrays
genes = list(adata.var.index)  # names of all genes in the dataset

# Create the DataFrame
print("Creating DataFrame...")
df = pd.DataFrame(adata.X)
df.index = arrays
df.columns = genes

# Check unique values in GZMB column
print("Unique values in GZMB column:", df['GZMB'].unique())

# Check data type of GZMB column
print("Data type of GZMB column:", df['GZMB'].dtype)

# Print a sample of the DataFrame
print("Sample of the DataFrame:", df.head())

# Adjust filtering logic for near-zero values
print("Filtering data...")
non_gzmb_cells = df[df['GZMB'] <= 1e-6].index.tolist()
gzmb_cells = df[df['GZMB'] > 1e-6].index.tolist()

# Create DataFrames for the non-GZMB and GZMB cells
non_gzmb_df = df.loc[non_gzmb_cells]
gzmb_df = df.loc[gzmb_cells]

# Extract gene names
non_gzmb_genes = non_gzmb_df.columns.tolist()
gzmb_genes = gzmb_df.columns.tolist()

# Specify a different directory for saving the files
output_dir = "output_files"
os.makedirs(output_dir, exist_ok=True)

# Save the entire filtered DataFrames to separate CSV files
print("Saving filtered DataFrames...")
non_gzmb_df.to_csv(os.path.join(output_dir, "non_gzmb_cells_genes_complete.csv"), index=False)
gzmb_df.to_csv(os.path.join(output_dir, "gzmb_cells_genes_complete.csv"), index=False)

# Function to save gene names in groups of 50
def save_gene_groups(genes, group_size, prefix):
    group_number = 1
    for i in range(0, len(genes), group_size):
        group = genes[i:i + group_size]
        if group:
            file_name = os.path.join(output_dir, f"{prefix}_group_{group_number}.csv")
            pd.DataFrame(group, columns=["Gene"]).to_csv(file_name, index=False)
            print(f"Saved {file_name}")
            group_number += 1

# Group size (50 genes per file)
group_size = 50

# Save the gene names in groups of 50
print("Saving gene names in groups of 50...")
save_gene_groups(non_gzmb_genes, group_size, "non_gzmb_genes")
save_gene_groups(gzmb_genes, group_size, "gzmb_genes")

print("Gene names for cells that do and do not produce granzyme B have been saved in groups of 50 and as complete files.")

# Define the file handler class for monitoring the folder
class FileHandler(FileSystemEventHandler):
    def __init__(self, folder_to_watch, database_url):
        self.folder_to_watch = folder_to_watch
        self.database_url = database_url

    def on_created(self, event):
        if event.is_directory:
            return
        file_path = event.src_path
        if file_path.endswith('.csv'):
            print(f"New CSV file detected: {file_path}")
            self.process_file(file_path)

    def process_file(self, file_path):
        print(f"Processing file: {file_path}")
        df = pd.read_csv(file_path)
        gene_names = df['Gene'].tolist()
        self.search_database(gene_names)

    def search_database(self, genes):
        # Placeholder for actual search logic
        print(f"Searching database at {self.database_url} with {len(genes)} gene names.")
        # Implement your search logic here

# Function to start monitoring the folder
def start_monitoring(folder_to_watch, database_url):
    event_handler = FileHandler(folder_to_watch, database_url)
    observer = Observer()
    observer.schedule(event_handler, folder_to_watch, recursive=False)
    observer.start()
    print(f"Started monitoring folder: {folder_to_watch}")
    try:
        while True:
            pass
    except KeyboardInterrupt:
        observer.stop()
    observer.join()

if __name__ == "__main__":
    folder_to_watch = "output_files"
    database_url = "https://singlecell.broadinstitute.org/single_cell/study/SCP642/cd8-lymphocytes-are-critical-for-early-control-of-tuberculosis-in-macaques?cluster=All%20Cells%20Clustering&spatialGroups=--&annotation=General_Celltypes--group--study&subsample=all#study-visualize"
    start_monitoring(folder_to_watch, database_url)
# Out:
# Loading data...
# Creating DataFrame...
# Unique values in GZMB column: [-0.4437231  -0.6130368  -0.6747464  ... -0.16763632  2.6062613
#   0.9008085 ]
# Data type of GZMB column: float32
# Sample of the DataFrame:                               AADAT     ABCA1     ABCA3     ABCA6     ABCA8  \
# Array2_28918_CAACGACACATC -0.167468  0.638589  1.007928 -0.227317 -0.065573
# Array2_28918_CAGTATGAGATC -0.167468  0.790691 -0.415276  0.098851 -0.065573
# Array2_28918_ACGTCGTCCCTT -0.167468  1.923116  0.261594 -0.227317 -0.065573
# Array2_28918_GCCAGCACATTA -0.167468  0.903512  0.122951  3.366497 -0.065573
# Array2_28918_CGAGTCTGTTAG -0.167468  1.757663  0.396551 -0.227317 -0.065573
#
#                               ABCB1    ABCB11     ABCC4     ABCC8     ABCC9  \
# Array2_28918_CAACGACACATC -0.193275 -0.080952  0.713645 -0.059069 -0.061314
# Array2_28918_CAGTATGAGATC -0.193275 -0.080952  0.661741 -0.059069 -0.061314
# Array2_28918_ACGTCGTCCCTT  0.226489 -0.080952 -0.483003 -0.059069 -0.061314
# Array2_28918_GCCAGCACATTA -0.193275 -0.080952  0.934337 -0.059069 -0.061314
# Array2_28918_CGAGTCTGTTAG -0.193275 -0.080952  0.262048 -0.059069 -0.061314
#
#                            ...    ZNF608    ZNF703    ZNF704    ZNF711  \
# Array2_28918_CAACGACACATC  ... -0.233297  0.021881  1.421112 -0.307914
# Array2_28918_CAGTATGAGATC  ... -0.233297 -0.451730  3.152616  0.041340
# Array2_28918_ACGTCGTCCCTT  ... -0.233297  1.175275  0.555045 -0.307914
# Array2_28918_GCCAGCACATTA  ... -0.233297 -0.177161 -0.239827 -0.307914
# Array2_28918_CGAGTCTGTTAG  ... -0.233297 -0.451730  1.071427 -0.307914
#
#                              ZNF75D    ZNF827   ZNF831       ZP3  rna76576  \
# Array2_28918_CAACGACACATC  0.021458 -0.255154 -0.27179 -0.122683  0.139296
# Array2_28918_CAGTATGAGATC -0.303056 -0.255154 -0.27179 -0.122683 -0.818924
# Array2_28918_ACGTCGTCCCTT -0.303056 -0.255154 -0.27179 -0.122683 -0.794223
# Array2_28918_GCCAGCACATTA -0.303056 -0.255154 -0.27179 -0.122683 -0.820615
# Array2_28918_CGAGTCTGTTAG -0.303056 -0.255154 -0.27179 -0.122683 -0.488761
#
#                            rna76578
# Array2_28918_CAACGACACATC -1.903382
# Array2_28918_CAGTATGAGATC -1.517206
# Array2_28918_ACGTCGTCCCTT -1.347134
# Array2_28918_GCCAGCACATTA -2.067089
# Array2_28918_CGAGTCTGTTAG -1.092246
#
# [5 rows x 3000 columns]
# Filtering data...
# Saving filtered DataFrames...
# Saving gene names in groups of 50...
# Saved output_files\non_gzmb_genes_group_1.csv
# Saved output_files\non_gzmb_genes_group_2.csv
# Saved output_files\non_gzmb_genes_group_3.csv
# Saved output_files\non_gzmb_genes_group_4.csv
# Saved output_files\non_gzmb_genes_group_5.csv
# Saved output_files\non_gzmb_genes_group_6.csv
# Saved output_files\non_gzmb_genes_group_7.csv
# Saved output_files\non_gzmb_genes_group_8.csv
# Saved output_files\non_gzmb_genes_group_9.csv
# Saved output_files\non_gzmb_genes_group_10.csv
# Saved output_files\non_gzmb_genes_group_11.csv
# Saved output_files\non_gzmb_genes_group_12.csv
# Saved output_files\non_gzmb_genes_group_13.csv
# Saved output_files\non_gzmb_genes_group_14.csv
# Saved output_files\non_gzmb_genes_group_15.csv
# Saved output_files\non_gzmb_genes_group_16.csv
# Saved output_files\non_gzmb_genes_group_17.csv
# Saved output_files\non_gzmb_genes_group_18.csv
# Saved output_files\non_gzmb_genes_group_19.csv
# Saved output_files\non_gzmb_genes_group_20.csv
# Saved output_files\non_gzmb_genes_group_21.csv
# Saved output_files\non_gzmb_genes_group_22.csv
# Saved output_files\non_gzmb_genes_group_23.csv
# Saved output_files\non_gzmb_genes_group_24.csv
# Saved output_files\non_gzmb_genes_group_25.csv
# Saved output_files\non_gzmb_genes_group_26.csv
# Saved output_files\non_gzmb_genes_group_27.csv
# Saved output_files\non_gzmb_genes_group_28.csv
# Saved output_files\non_gzmb_genes_group_29.csv
# Saved output_files\non_gzmb_genes_group_30.csv
# Saved output_files\non_gzmb_genes_group_31.csv
# Saved output_files\non_gzmb_genes_group_32.csv
# Saved output_files\non_gzmb_genes_group_33.csv
# Saved output_files\non_gzmb_genes_group_34.csv
# Saved output_files\non_gzmb_genes_group_35.csv
# Saved output_files\non_gzmb_genes_group_36.csv
# Saved output_files\non_gzmb_genes_group_37.csv
# Saved output_files\non_gzmb_genes_group_38.csv
# Saved output_files\non_gzmb_genes_group_39.csv
# Saved output_files\non_gzmb_genes_group_40.csv
# Saved output_files\non_gzmb_genes_group_41.csv
# Saved output_files\non_gzmb_genes_group_42.csv
# Saved output_files\non_gzmb_genes_group_43.csv
# Saved output_files\non_gzmb_genes_group_44.csv
# Saved output_files\non_gzmb_genes_group_45.csv
# Saved output_files\non_gzmb_genes_group_46.csv
# Saved output_files\non_gzmb_genes_group_47.csv
# Saved output_files\non_gzmb_genes_group_48.csv
# Saved output_files\non_gzmb_genes_group_49.csv
# Saved output_files\non_gzmb_genes_group_50.csv
# Saved output_files\non_gzmb_genes_group_51.csv
# Saved output_files\non_gzmb_genes_group_52.csv
# Saved output_files\non_gzmb_genes_group_53.csv
# Saved output_files\non_gzmb_genes_group_54.csv
# Saved output_files\non_gzmb_genes_group_55.csv
# Saved output_files\non_gzmb_genes_group_56.csv
# Saved output_files\non_gzmb_genes_group_57.csv
# Saved output_files\non_gzmb_genes_group_58.csv
# Saved output_files\non_gzmb_genes_group_59.csv
# Saved output_files\non_gzmb_genes_group_60.csv
# Saved output_files\gzmb_genes_group_1.csv
# Saved output_files\gzmb_genes_group_2.csv
# Saved output_files\gzmb_genes_group_3.csv
# Saved output_files\gzmb_genes_group_4.csv
# Saved output_files\gzmb_genes_group_5.csv
# Saved output_files\gzmb_genes_group_6.csv
# Saved output_files\gzmb_genes_group_7.csv
# Saved output_files\gzmb_genes_group_8.csv
# Saved output_files\gzmb_genes_group_9.csv
# Saved output_files\gzmb_genes_group_10.csv
# Saved output_files\gzmb_genes_group_11.csv
# Saved output_files\gzmb_genes_group_12.csv
# Saved output_files\gzmb_genes_group_13.csv
# Saved output_files\gzmb_genes_group_14.csv
# Saved output_files\gzmb_genes_group_15.csv
# Saved output_files\gzmb_genes_group_16.csv
# Saved output_files\gzmb_genes_group_17.csv
# Saved output_files\gzmb_genes_group_18.csv
# Saved output_files\gzmb_genes_group_19.csv
# Saved output_files\gzmb_genes_group_20.csv
# Saved output_files\gzmb_genes_group_21.csv
# Saved output_files\gzmb_genes_group_22.csv
# Saved output_files\gzmb_genes_group_23.csv
# Saved output_files\gzmb_genes_group_24.csv
# Saved output_files\gzmb_genes_group_25.csv
# Saved output_files\gzmb_genes_group_26.csv
# Saved output_files\gzmb_genes_group_27.csv
# Saved output_files\gzmb_genes_group_28.csv
# Saved output_files\gzmb_genes_group_29.csv
# Saved output_files\gzmb_genes_group_30.csv
# Saved output_files\gzmb_genes_group_31.csv
# Saved output_files\gzmb_genes_group_32.csv
# Saved output_files\gzmb_genes_group_33.csv
# Saved output_files\gzmb_genes_group_34.csv
# Saved output_files\gzmb_genes_group_35.csv
# Saved output_files\gzmb_genes_group_36.csv
# Saved output_files\gzmb_genes_group_37.csv
# Saved output_files\gzmb_genes_group_38.csv
# Saved output_files\gzmb_genes_group_39.csv
# Saved output_files\gzmb_genes_group_40.csv
# Saved output_files\gzmb_genes_group_41.csv
# Saved output_files\gzmb_genes_group_42.csv
# Saved output_files\gzmb_genes_group_43.csv
# Saved output_files\gzmb_genes_group_44.csv
# Saved output_files\gzmb_genes_group_45.csv
# Saved output_files\gzmb_genes_group_46.csv
# Saved output_files\gzmb_genes_group_47.csv
# Saved output_files\gzmb_genes_group_48.csv
# Saved output_files\gzmb_genes_group_49.csv
# Saved output_files\gzmb_genes_group_50.csv
# Saved output_files\gzmb_genes_group_51.csv
# Saved output_files\gzmb_genes_group_52.csv
# Saved output_files\gzmb_genes_group_53.csv
# Saved output_files\gzmb_genes_group_54.csv
# Saved output_files\gzmb_genes_group_55.csv
# Saved output_files\gzmb_genes_group_56.csv
# Saved output_files\gzmb_genes_group_57.csv
# Saved output_files\gzmb_genes_group_58.csv
# Saved output_files\gzmb_genes_group_59.csv
# Saved output_files\gzmb_genes_group_60.csv
# Gene names for cells that do and do not produce granzyme B have been saved in groups of 50 and as complete files.
# Started monitoring folder: output_files
# New CSV file detected: output_files\non_gzmb_genes_complete.csv
# Processing file: output_files\non_gzmb_genes_complete.csv
# Searching database at https://singlecell.broadinstitute.org/single_cell/study/SCP642/cd8-lymphocytes-are-critical-for-early-control-of-tuberculosis-in-macaques?cluster=All%20Cells%20Clustering&spatialGroups=--&annotation=General_Celltypes--group--study&subsample=all#study-visualize with 3000 gene names.
# New CSV file detected: output_files\gzmb_genes_complete.csv
# Processing file: output_files\gzmb_genes_complete.csv
# Searching database at https://singlecell.broadinstitute.org/single_cell/study/SCP642/cd8-lymphocytes-are-critical-for-early-control-of-tuberculosis-in-macaques?cluster=All%20Cells%20Clustering&spatialGroups=--&annotation=General_Celltypes--group--study&subsample=all#study-visualize with 3000 gene names.
# New CSV file detected: output_files\celltype_vs_granzyme_expression.csv
# Processing file: output_files\celltype_vs_granzyme_expression.csv
# Exception in thread Thread-5:
# Traceback (most recent call last):
#   File "C:\Users\abhic\anaconda3\Lib\site-packages\pandas\core\indexes\base.py", line 3805, in get_loc
#     return self._engine.get_loc(casted_key)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "index.pyx", line 167, in pandas._libs.index.IndexEngine.get_loc
#   File "index.pyx", line 196, in pandas._libs.index.IndexEngine.get_loc
#   File "pandas\\_libs\\hashtable_class_helper.pxi", line 7081, in pandas._libs.hashtable.PyObjectHashTable.get_item
#   File "pandas\\_libs\\hashtable_class_helper.pxi", line 7089, in pandas._libs.hashtable.PyObjectHashTable.get_item
# KeyError: 'Gene'
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "C:\Users\abhic\anaconda3\Lib\threading.py", line 1073, in _bootstrap_inner
#     self.run()
#   File "C:\Users\abhic\anaconda3\Lib\site-packages\watchdog\observers\api.py", line 223, in run
#     self.dispatch_events(self.event_queue)
#   File "C:\Users\abhic\anaconda3\Lib\site-packages\watchdog\observers\api.py", line 402, in dispatch_events
#     handler.dispatch(event)
#   File "C:\Users\abhic\anaconda3\Lib\site-packages\watchdog\events.py", line 224, in dispatch
#     {
#   File "C:\Users\abhic\AppData\Local\Temp\ipykernel_26300\1266133571.py", line 85, in on_created
#   File "C:\Users\abhic\AppData\Local\Temp\ipykernel_26300\1266133571.py", line 90, in process_file
#   File "C:\Users\abhic\anaconda3\Lib\site-packages\pandas\core\frame.py", line 4102, in __getitem__
#     indexer = self.columns.get_loc(key)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\abhic\anaconda3\Lib\site-packages\pandas\core\indexes\base.py", line 3812, in get_loc
#     raise KeyError(key) from err
# KeyError: 'Gene'
